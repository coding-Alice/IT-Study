# %% [markdown]
# <a href="https://colab.research.google.com/github/coding-Alice/IT-Study/blob/main/youtube_api_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from googleapiclient.discovery import build

import warnings # 경고창 무시
warnings.filterwarnings('ignore')

# %%
api_key = "AIzaSyCEpeWlCrgg0p6M0RlfnMgxLrxqtfFEx-c"
video_id = "LSZzJN3ebwg"

# %%
youtube = build('youtube', 'v3', developerKey=api_key)
#response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()

# %%
comments = list()
nextPageToken = None

while(1) :
  response = youtube.commentThreads().list(
    part='snippet,replies',
    videoId= video_id,
    pageToken = nextPageToken,
    maxResults=1000
  ).execute()

  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])

    if item['snippet']['totalReplyCount'] > 0:
      try:
        for reply_item in item['replies']['comments']:
            reply = reply_item['snippet']
            comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
      except:
        continue
  if 'nextPageToken' in response :
    nextPageToken = response['nextPageToken']
  else :
    break

# %%
df = pd.DataFrame(comments)
df
# Out:
#                                                      0         1  \
# 0    안녕하세요, 싼타입니다!\r<br>\r<br>영상 내 <a href="https:/...      동심파괴
# 1                                          내가 말할려고 했는데  B Rabbit
# 2                                                 괜찮아요      창일 김
# 3                                      괜찮습니다 실수는누구나하죠!        ㅋㅋ
# 4                                                 괜찮아요        김식
# ..                                                 ...       ...
# 520                                                 우와       김건영
# 521                                                  오    뉴비 달걀이
# 522                                                 1빠      은비가비
# 523                                                오..      아론 김
# 524                                               오우..       박아림
#
#                         2    3
# 0    2022-05-27T00:03:00Z  126
# 1    2022-06-11T05:11:46Z    0
# 2    2022-06-10T13:23:12Z    0
# 3    2022-06-06T06:57:31Z    0
# ...

# %%
# 테이블에 제목 붙이기 
df.columns = ['comment', 'author', 'date', 'num_likes']

# %%
# 날짜 내림차순으로 정렬해서 확인 
df.sort_values(by="date", ascending=False)
# Out:
#                                                comment          author  \
# 228  저두 저희 할머니 할아버지 오래오래 건강하셨으면해용<br><br>마음이 맞는거같은데...             쉬이벌
# 6                      이승만 사망은 1948 아니고 1965임. 확인 부탁..             이재호
# 7                                                안녕하세요            혜진 임
# 8                       백십여덟???<br>백십팔세도 아니고 뭔 해괴한 소리?  luxmea veritas
# 209  저는 68 인데 노인복지관 건강관리실에서<br>봉사활동 열심히 하고<br>서예도 배...             도혜맘
# ..                                                 ...             ...
# 520                                                 우와             김건영
# 521                                                  오          뉴비 달걀이
# 522                                                 1빠            은비가비
# 523                                                오..            아론 김
# 524                                               오우..             박아림
#
#                      date  num_likes
# 228  2022-06-12T23:44:42Z          0
# 6    2022-06-12T13:05:35Z          0
# ...

# %%
# results.csv라는 파일로 파일 내보내기 
df.to_csv('results.csv', index=None)
